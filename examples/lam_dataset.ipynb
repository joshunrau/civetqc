# %%
from civetqc.civetdata import CivetData

# %%
data = CivetData(
    path_usrqc = "/Users/joshua/Developer/civetqc/data/LAM/LAM_T1w.csv",
    path_civout = "/Users/joshua/Developer/civetqc/data/LAM/QC/civet_LAM_.csv")

# %%
print(data)

# %%
len(data.usrqc["Full_ID"])

# %%
data.civout.shape[0]

# %%
data.print_civout()
