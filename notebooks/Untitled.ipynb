# %%
import numpy as np
import pandas as pd
import seaborn as sns
import sys
sys.path.insert(0, "/Users/joshua/Developer/civetqc")
pd.set_option('display.max_columns', None)

# %%
from civetqc.dataset import Dataset
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

# %%
data = Dataset()

# %%
data.train["Features"].shape
# Out:
# (849, 29)

# %%
data.test["Features"].shape
# Out:
# (366, 29)

# %%
clf = RandomForestClassifier()

# %%
clf.fit(data.train["Features"], data.train["Target"])
# Out:
# RandomForestClassifier()

# %%
pred = clf.predict(data.test["Features"])

# %%
print(classification_report(data.test["Target"], pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       353
#            1       0.60      0.23      0.33        13
#
#     accuracy                           0.97       366
#    macro avg       0.79      0.61      0.66       366
# weighted avg       0.96      0.97      0.96       366
