# %%
import sys
sys.path.append("/Users/joshua/Developer/civetqc")

# %%
from civetqc.data.dataset import Dataset

# %%
data = Dataset.from_file("/Users/joshua/Developer/civetqc/data/processed/civetqc_data_Feb20.csv")

# %%
data.df
# Out:
#            ID  QC  XSTEP  YSTEP  ZSTEP  MASK_ERROR  CSF_PERCENT  GM_PERCENT  \
# 0         001   0   0.75   0.75   0.75        9.78        11.76       45.90
# 1         002   0   0.75   0.75   0.75        8.55        11.22       48.20
# 2         003   0   0.75   0.75   0.75        9.54        12.79       46.89
# 3         004   0   0.75   0.75   0.75        9.42        10.03       46.99
# 4         005   0   0.75   0.75   0.75        8.06         9.50       49.63
# ...       ...  ..    ...    ...    ...         ...          ...         ...
# 1210  s2_98_2   1   1.00   1.00   1.00        7.99         8.68       42.84
# 1211  s2_98_3   0   1.00   1.00   1.00        7.77         9.12       44.67
# 1212  s2_99_1   0   1.00   1.00   1.00        8.15         6.93       41.22
# 1213  s2_99_2   0   1.00   1.00   1.00        8.08         7.71       39.82
# 1214  s2_99_3   0   1.00   1.00   1.00        7.87         7.88       41.05
#
# ...
