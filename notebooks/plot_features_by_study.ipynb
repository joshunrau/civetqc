# %%
import sys
sys.path.insert(0, "/Users/joshua/Developer/civetqc")

# %%
from civetqc.data.dataset import Dataset

# %%
dataset = Dataset()

# %%
studies = Dataset.datasets_by_study()

# %%
studies
# Out:
# {'FEP': <civetqc.data.dataset.Dataset at 0x14e3a12e0>,
#  'LAM': <civetqc.data.dataset.Dataset at 0x14e2ec2b0>,
#  'INSIGHT': <civetqc.data.dataset.Dataset at 0x105b15f40>,
#  'TOPSY': <civetqc.data.dataset.Dataset at 0x105b6cfd0>}

# %%
for name, study in studies.items():
    print(study.get_target_counts())
# Out:
# Target Counts:
#
# ALL
# Acceptable: 443
# Unacceptable: 13
#
# ALL
# Acceptable: 443
# Unacceptable: 13
#
# Target Counts:
#
# ALL
# Acceptable: 322
# Unacceptable: 11
#
# ALL
# Acceptable: 322
# Unacceptable: 11
#
# Target Counts:
#
# ALL
# Acceptable: 178
# Unacceptable: 4
#
# ALL
# Acceptable: 178
# Unacceptable: 4
#
# Target Counts:
#
# ALL
# Acceptable: 96
# Unacceptable: 19
#
# ALL
# Acceptable: 96
# Unacceptable: 19
