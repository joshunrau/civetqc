# %%
import sys
sys.path.insert(0, "/Users/joshua/Developer/civetqc")

# %%
from civetqc.data.dataset import Dataset

# %%
x = Dataset()

# %%
x.features
# Out:
# array([[1670.63   , 1419.25   ,  678.97   , ...,   75.7    ,  613.95   ,
#           45.39   ],
#        [1284.7    , 1068.87   ,  533.11   , ...,   61.31   ,  448.77   ,
#           43.71   ],
#        [1267.21   , 1054.11   ,  529.85   , ...,   55.93   ,  439.21   ,
#           43.38   ],
#        ...,
#        [1207.30142,  898.52256,  392.113  , ...,   60.28723,  388.77557,
#           39.39   ],
#        [1635.49851, 1244.39068,  581.276  , ...,   85.01544,  535.70531,
#           39.25   ],
#        [1428.09464, 1172.40126,  547.371  , ...,   82.64505,  478.54653,
#           38.34   ]])

# %%
x.feature_names
# Out:
# array(['BRAIN_VOL', 'CEREBRUM_VOL', 'CORTICAL_GM', 'CSF_PERCENT',
#        'CSF_VENT_VOL', 'GI_LEFT', 'GI_RIGHT', 'GM_PERCENT',
#        'GRAY_LEFT_RES', 'GRAY_RIGHT_RES', 'LAPLACIAN_MAX',
#        'LAPLACIAN_MEAN', 'LAPLACIAN_MIN', 'LEFT_GM_AREA', 'LEFT_INTER',
#        'LEFT_MID_AREA', 'LEFT_SURF_SURF', 'LEFT_WM_AREA', 'MASK_ERROR',
#        'RIGHT_GM_AREA', 'RIGHT_INTER', 'RIGHT_MID_AREA',
#        'RIGHT_SURF_SURF', 'RIGHT_WM_AREA', 'SC_PERCENT', 'SC_VOL',
#        'STUDY_ID=FEP', 'STUDY_ID=INSIGHT', 'STUDY_ID=LAM',
#        'STUDY_ID=TOPSY', 'SUBGM_VOL', 'WHITE_VOL', 'WM_PERCENT'],
#       dtype=object)
