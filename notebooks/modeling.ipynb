# %%
from civetqc.data.dataset import Dataset

# %%
data = Dataset()

# %%
print(data)
# Out:
# Target Counts:
#
# All
# Acceptable: 1039
# Unacceptable: 47
#
# Train
# Acceptable: 779
# Unacceptable: 35
#
# Test
# Acceptable: 260
# Unacceptable: 12
#
# -------------------------------------------------------------------------------
# Mean and Standard Deviation of Features by QC Rating
#
# MASK_ERROR
# Acceptable: Mean=8.73, SD=2.13
# Unacceptable: Mean=9.99, SD=3.13
#
# WM_PERCENT
# Acceptable: Mean=41.87, SD=3.52
# Unacceptable: Mean=41.22, SD=4.41
#
# GM_PERCENT
# Acceptable: Mean=46.53, SD=3.19
# Unacceptable: Mean=45.50, SD=4.18
#
# CSF_PERCENT
# Acceptable: Mean=8.84, SD=2.34
# Unacceptable: Mean=10.55, SD=3.75
#
# SC_PERCENT
# Acceptable: Mean=2.76, SD=0.35
# Unacceptable: Mean=2.72, SD=0.40
#
# BRAIN_VOL
# Acceptable: Mean=1472.17, SD=208.40
# Unacceptable: Mean=1388.14, SD=177.94
#
# CEREBRUM_VOL
# Acceptable: Mean=1218.48, SD=174.21
# Unacceptable: Mean=1119.69, SD=160.02
#
# CORTICAL_GM
# Acceptable: Mean=585.80, SD=80.44
# Unacceptable: Mean=520.23, SD=77.38
#
# WHITE_VOL
# Acceptable: Mean=517.39, SD=82.41
# Unacceptable: Mean=485.44, SD=79.18
#
# SUBGM_VOL
# Acceptable: Mean=71.27, SD=13.00
# Unacceptable: Mean=71.21, SD=10.39
#
# SC_VOL
# Acceptable: Mean=37.74, SD=5.77
# Unacceptable: Mean=34.83, SD=6.06
#
# CSF_VENT_VOL
# Acceptable: Mean=15.77, SD=8.92
# Unacceptable: Mean=15.12, SD=7.65
#
# LEFT_WM_AREA
# Acceptable: Mean=101170.56, SD=9976.06
# Unacceptable: Mean=98760.24, SD=11678.06
#
# LEFT_MID_AREA
# Acceptable: Mean=103614.27, SD=9909.91
# Unacceptable: Mean=100441.24, SD=10077.89
#
# LEFT_GM_AREA
# Acceptable: Mean=112393.13, SD=10756.98
# Unacceptable: Mean=108695.13, SD=10368.39
#
# RIGHT_WM_AREA
# Acceptable: Mean=101504.95, SD=10050.84
# Unacceptable: Mean=99126.18, SD=11225.09
#
# RIGHT_MID_AREA
# Acceptable: Mean=103899.98, SD=9973.28
# Unacceptable: Mean=100782.56, SD=9952.71
#
# RIGHT_GM_AREA
# Acceptable: Mean=112716.36, SD=10769.08
# Unacceptable: Mean=109019.92, SD=10375.84
#
# GI_LEFT
# Acceptable: Mean=2.46, SD=0.09
# Unacceptable: Mean=2.48, SD=0.11
#
# GI_RIGHT
# Acceptable: Mean=2.47, SD=0.09
# Unacceptable: Mean=2.50, SD=0.10
#
# LEFT_INTER
# Acceptable: Mean=44.72, SD=33.88
# Unacceptable: Mean=83.62, SD=90.16
#
# RIGHT_INTER
# Acceptable: Mean=41.31, SD=32.68
# Unacceptable: Mean=70.66, SD=52.56
#
# LEFT_SURF_SURF
# Acceptable: Mean=23.25, SD=30.89
# Unacceptable: Mean=77.83, SD=116.83
#
# RIGHT_SURF_SURF
# Acceptable: Mean=22.36, SD=31.43
# Unacceptable: Mean=65.96, SD=92.54
#
# LAPLACIAN_MIN
# Acceptable: Mean=8.40, SD=2.08
# Unacceptable: Mean=5.74, SD=3.70
#
# LAPLACIAN_MAX
# Acceptable: Mean=10.87, SD=0.07
# Unacceptable: Mean=11.10, SD=0.51
#
# LAPLACIAN_MEAN
# Acceptable: Mean=10.00, SD=0.00
# Unacceptable: Mean=9.94, SD=0.14
#
# GRAY_LEFT_RES
# Acceptable: Mean=0.01, SD=0.00
# Unacceptable: Mean=0.05, SD=0.17
#
# GRAY_RIGHT_RES
# Acceptable: Mean=0.01, SD=0.00
# Unacceptable: Mean=0.07, SD=0.24

# %%
class Model:
    
    def __init__(self, clf, data: Dataset) -> None:
        self.data = data
        self.clf = clf.fit(data.train.features, data.train.target)
        self.predicted = self.clf.predict(data.test.features)
    
    @property
    def f2_score(self):
        return fbeta_score(self.data.test.target, self.predicted, beta=2)
    
    @property
    def classification_report(self):
        return classification_report(data.test.target, self.predicted)

# %%
for balancing_method in Dataset.balancing_methods:
    best_model = None
    for test_size in [.25, .33, .5]:
        data = Dataset(test_size, balancing_method)
        model = Model(RandomForestClassifier(n_estimators=100, random_state=0), data)
        print(f"Test Size: {data.test_size}")
        print(f"Balancing Method: {data.balancing_method}\n")
        print(f"F2_Score: {model.f2_score}")
        
#print(balancing_method)
#model = Model(RandomForestClassifier(n_estimators=100, random_state=0), balancing_method=balancing_method)
#print(model.classification_report)

# %%
from sklearn.metrics import balanced_accuracy_score
data = Dataset()
data.train
clf = BalancedRandomForestClassifier()

# %%
clf.fit(data.train.features, data.train.target)

# %%
predicted = clf.predict(data.test.features)

# %%
balanced_accuracy_score(data.test.target, predicted)
