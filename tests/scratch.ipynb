# %%
import pandas as pd

# %%
civet_output = pd.read_csv("/Users/joshua/Developer/civetpy/data/LAM/QC/civet_LAM_.csv")
user_ratings = pd.read_csv("/Users/joshua/Developer/civetpy/data/LAM/user_ratings.csv")

# %%
user_ratings["ID"]
# Out:
# 0      7001_1
# 1      7001_2
# 2      7001_3
# 3      7002_1
# 4      7002_2
#         ...
# 404    8088_1
# 405    8088_2
# 406    8089_1
# 407    8089_2
# 408    8090_1
# Name: ID, Length: 409, dtype: object

# %%
len(civet_output["ID"].unique()) == len(civet_output["ID"])
# Out:
# True

# %%
pd.merge(civet_output, user_ratings)
# Out:
#          ID  XSTEP  YSTEP  ZSTEP  MASK_ERROR  WM_PERCENT  GM_PERCENT  \
# 0    7001_1    1.0    1.0    1.0        9.81       37.54       50.27
# 1    7001_2    1.0    1.0    1.0        9.34       38.59       49.91
# 2    7001_3    1.0    1.0    1.0        9.39       37.08       51.23
# 3    7002_1    1.0    1.0    1.0        7.60       38.32       51.29
# 4    7002_2    1.0    1.0    1.0        7.69       34.53       54.92
# ..      ...    ...    ...    ...         ...         ...         ...
# 341  8064_1    1.0    1.0    1.0        6.89       42.12       48.81
# 342  8064_2    1.0    1.0    1.0        6.85       42.36       47.80
# 343  8067_1    1.0    1.0    1.0        8.13       40.20       47.68
# 344  8069_1    1.0    1.0    1.0        9.69       35.31       48.52
# 345  8070_1    1.0    1.0    1.0       11.37       43.38       43.32
#
#      CSF_PERCENT  SC_PERCENT  BRAIN_VOL  ...  \
# 0           9.55        2.65    1416.34  ...
# ...
